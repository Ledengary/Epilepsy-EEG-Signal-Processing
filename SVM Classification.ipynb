# %%
import numpy as np
from matplotlib import pyplot as plt
from sklearn.metrics import confusion_matrix
from sklearn import svm
from sklearn.model_selection import train_test_split
import pickle
from sklearn.metrics import classification_report
from sklearn.preprocessing import MinMaxScaler
from sklearn.utils import shuffle
from scipy import signal

# %%
pickles_address = '/content/drive/MyDrive/Brain-Computer Interfaces/Epilepsy Dataset/Pickles/'
A_address = '/content/drive/MyDrive/Brain-Computer Interfaces/Epilepsy Dataset/Z/'
B_address = '/content/drive/MyDrive/Brain-Computer Interfaces/Epilepsy Dataset/O/'
C_address = '/content/drive/MyDrive/Brain-Computer Interfaces/Epilepsy Dataset/N/'
D_address = '/content/drive/MyDrive/Brain-Computer Interfaces/Epilepsy Dataset/F/'
E_address = '/content/drive/MyDrive/Brain-Computer Interfaces/Epilepsy Dataset/S/'

# %%
with open(pickles_address + 'As_rhyme_features_TF.pickle', 'rb') as f:
    As_features_T = pickle.load(f)
with open(pickles_address + 'Bs_rhyme_features_TF.pickle', 'rb') as f:
    Bs_features_T = pickle.load(f)
with open(pickles_address + 'Cs_rhyme_features_TF.pickle', 'rb') as f:
    Cs_features_T = pickle.load(f)
with open(pickles_address + 'Ds_rhyme_features_TF.pickle', 'rb') as f:
    Ds_features_T = pickle.load(f)
with open(pickles_address + 'Es_rhyme_features_TF.pickle', 'rb') as f:
    Es_features_T = pickle.load(f)
print('As_features_TF', As_features_T.shape)
print('Bs_features_TF', Bs_features_T.shape)
print('Cs_features_TF', Cs_features_T.shape)
print('Ds_features_TF', Ds_features_T.shape)
print('Es_features_TF', Es_features_T.shape)
# Out:
# As_features_T (35, 100)
# Bs_features_T (35, 100)
# Cs_features_T (35, 100)
# Ds_features_T (35, 100)
# Es_features_T (35, 100)

# %%
X = list(As_features_T.T) + list(Bs_features_T.T) + list(Cs_features_T.T) + list(Ds_features_T.T)
y = [0] * (len(As_features_T.T) + len(Bs_features_T.T)) + [1] * (len(Cs_features_T.T) + len(Ds_features_T.T))
len(X), len(y)
# Out:
# (400, 400)

# %%
for i in range(len(X)):
    X[i] = [X[i][j] if str(X[i][j]) != '-inf' else 0 for j in range(len(X[i]))]
print(X[0])
# Out:
# [-217.27682724238545, 15933.277547532409, -0.2165598191753221, 0.01404821262728806, 0, 63142.49720404982, 44.094383675952315, -4.761950714365507, 10206.537991105393, 0.011900810175219365, -0.030682028899508218, 0, 10229.21416571144, 44.094383675952315, 0.9819857063805277, 5481.088501027444, 0.2985792057662005, 0.47501419920499277, 0, 5482.05279695498, 44.094383675952315, -0.07184972203442146, 507.59761191015247, 0.16149131673495162, 0.4829112779336939, 0, 507.6027742927089, 44.094383675952315, -0.04308611922673082, 18.448510740300012, 0.29300388260267696, 5.969478396159166, 0, 18.450367153970035, 44.094383675952315]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=True, random_state=1)
len(X_train), len(y_train), len(X_test), len(y_test)
# Out:
# (320, 320, 80, 80)

# %%
print(X_train[0])
# Out:
# [33.69959745795766, 13400.335414447884, 0.03645948430125631, 0.8027615279785882, 0, 14535.99828327627, 44.094383675952315, 5.5436696265184295, 8767.627093174719, -0.2209795965424684, 0.1627618114425835, 0, 8798.359366102703, 44.094383675952315, -0.4551701682585736, 4748.516164150261, 0.004916633856635844, 0.2584119443271864, 0, 4748.723344032333, 44.094383675952315, -0.09734940967081254, 943.8144604575851, -0.06240878059915051, 0.095930259625995, 0, 943.8239373651483, 44.094383675952315, 0.07518245668536813, 27.745357758020386, -0.06613270265846355, 0.07485159144128994, 0, 27.751010159813635, 44.094383675952315]

# %%
scaling = MinMaxScaler(feature_range=(-1,1)).fit(X_train)
X_train = scaling.transform(X_train)
X_test = scaling.transform(X_test)

# %%
print(X_train[0])
# Out:
# [ 0.26498527 -0.99169187 -0.18502477 -0.61022091 -1.         -0.99188582
#  -1.          0.29408716 -0.96026479  0.01657146 -0.89746751 -1.
#  -0.96033116 -1.          0.06231688 -0.78789984  0.41503527 -0.92938469
#  -1.         -0.78813392 -1.         -0.38104026 -0.45189624  0.04117452
#  -0.99601599 -1.         -0.45189805 -1.          0.21427216 -0.80200762
#  -0.32324208 -0.99574119 -1.         -0.80197347 -1.        ]

# %%
clf = svm.SVC(kernel='poly')
clf.fit(X_train, y_train)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='poly',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
y_pred = clf.predict(X_test)

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[26,  7],
#        [ 1, 46]])

# %%
correctness = [1 if y_test[i] == y_pred[i] else 0 for i in range(len(y_pred))]
print('Accuracy:', (sum(correctness) / len(correctness)) * 100)
# Out:
# Accuracy: 90.0

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.79      0.87        33
#            1       0.87      0.98      0.92        47
#
#     accuracy                           0.90        80
#    macro avg       0.92      0.88      0.89        80
# weighted avg       0.91      0.90      0.90        80

# %% [markdown]
# K-Fold Cross Validation

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

# %%
cv = KFold(n_splits=10, random_state=1, shuffle=True)
scaling = MinMaxScaler(feature_range=(-1,1)).fit(X)
X = scaling.transform(X)
clf = svm.SVC(kernel='poly')
scores = cross_val_score(clf, X, y, scoring='accuracy', cv=cv, n_jobs=-1)
print('Accuracy: %.3f' % (np.mean(scores)))
# Out:
# Accuracy: 0.915

# %% [markdown]
# LeaveOneOut

# %%
from numpy import mean
from numpy import std
from sklearn.model_selection import LeaveOneOut
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier

# %%
cv = LeaveOneOut()
clf = svm.SVC(kernel='poly')
scaling = MinMaxScaler(feature_range=(-1,1)).fit(X)
X = scaling.transform(X)
scores = cross_val_score(clf, X, y, scoring='accuracy', cv=cv, n_jobs=-1)
print('Accuracy: %.3f' % (np.mean(scores)))
# Out:
# Accuracy: 0.925

# %% [markdown]
# Multi-label Classification

# %%
X = list(As_features_T.T) + list(Bs_features_T.T) + list(Cs_features_T.T) + list(Ds_features_T.T) + list(Es_features_T.T)
y = [0] * (len(As_features_T.T) + len(Bs_features_T.T)) + [1] * (len(Cs_features_T.T) + len(Ds_features_T.T)) + [2] *  len(Es_features_T.T)
scaling = MinMaxScaler(feature_range=(-1,1)).fit(X)
X = scaling.transform(X)
print(len(X), len(y))

for i in range(len(X)):
    X[i] = [X[i][j] if str(X[i][j]) != '-inf' else 0 for j in range(len(X[i]))]
print(X[0])

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=True, random_state=1)
print(len(X_train), len(y_train), len(X_test), len(y_test))

clf = svm.SVC(kernel='poly', decision_function_shape='ovo')
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
print(confusion_matrix(y_test, y_pred))

correctness = [1 if y_test[i] == y_pred[i] else 0 for i in range(len(y_pred))]
print('HoldOutMethod Accuracy:', (sum(correctness) / len(correctness)) * 100)
print(classification_report(y_test, y_pred))

cv = KFold(n_splits=10, random_state=1, shuffle=True)
clf = svm.SVC(kernel='poly', decision_function_shape='ovo')
scores = cross_val_score(clf, X, y, scoring='accuracy', cv=cv, n_jobs=-1)
print('KFold Accuracy: %.3f' % (np.mean(scores)))

cv = LeaveOneOut()
clf = svm.SVC(kernel='poly', decision_function_shape='ovo')
scores = cross_val_score(clf, X, y, scoring='accuracy', cv=cv, n_jobs=-1)
print('LeaveOneOut Accuracy: %.3f' % (np.mean(scores)))
